# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandrasarah/projetos-python/blob/main/regressao_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dados = pd.read_excel('/content/drive/MyDrive/Programaria/analise_dados_mod7_(1).xlsx')

# %%
dados.head()
# Out:
#                                  ID  IDADE FAIXA IDADE     GENERO  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
#                           ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0                                           NaN            True
# 1  Aprovação em processos seletivos/entrevistas            True
# 2                                           NaN            True
# 3                                           NaN            True
# 4                                           NaN            True
#
#         ESTADO ONDE MORA  ...  \
# 0  Distrito Federal (DF)  ...
# 1              Pará (PA)  ...
# 2  Distrito Federal (DF)  ...
# 3      Minas Gerais (MG)  ...
# 4              Pará (PA)  ...
#
#   Você pretende mudar de emprego nos próximos 6 meses?  \
# 0  Não estou buscando e não pretendo mudar de emp...
# 1  Estou em busca de oportunidades dentro ou fora...
# 2  Não estou buscando, mas me considero aberto a ...
# 3  Não estou buscando, mas me considero aberto a ...
# 4  Não estou buscando, mas me considero aberto a ...
#
#   Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?  \
# 0                                         Benefícios
# 1  Remuneração/Salário, Plano de carreira e oport...
# 2  Remuneração/Salário, Flexibilidade de trabalho...
# 3  Remuneração/Salário, Flexibilidade de trabalho...
# 4  Remuneração/Salário, Oportunidade de aprendiza...
#
#             Atualmente qual a sua forma de trabalho?  \
# 0                             Modelo 100% presencial
# 1                             Modelo 100% presencial
# 2  Modelo híbrido com dias fixos de trabalho pres...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#            Qual a forma de trabalho ideal para você?  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
# 1  Modelo híbrido flexível (o funcionário tem lib...
# 2  Modelo híbrido flexível (o funcionário tem lib...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#   Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 0   Vou aceitar e retornar ao modelo 100% presencial
# 1   Vou aceitar e retornar ao modelo 100% presencial
# 2  Vou procurar outra oportunidade no modelo híbr...
# 3  Vou procurar outra oportunidade no modelo híbr...
# 4   Vou aceitar e retornar ao modelo 100% presencial
#
#                Sua empresa passu por Layoff em 2022?  \
# 0  Não ocorreram layoffs/demissões em massa na em...
# 1  Não ocorreram layoffs/demissões em massa na em...
# 2  Não ocorreram layoffs/demissões em massa na em...
# 3  Não ocorreram layoffs/demissões em massa na em...
# 4  Não ocorreram layoffs/demissões em massa na em...
#
#                                              Atuacao  \
# 0                                Engenharia de Dados
# 1                                             Gestor
# 2  desenvolve modelos preditivos e algoritmos de ...
# 3  desenvolve modelos preditivos e algoritmos de ...
# 4                                      Outra atuação
#
#   Quais das linguagens listadas abaixo você utiliza no trabalho? EM_BUSCA  \
# 0                                                SQL                  0.0
# 1                                                NaN                  1.0
# 2                                                  1                  0.0
# 3                                                  0                  0.0
# 4                                                SQL                  0.0
#
#    ABERTO_OPORTUNIDADES
# 0                   0.0
# 1                   0.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
#
# [5 rows x 46 columns]

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GEARACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?',
#        'EM_BUSCA', 'ABERTO_OPORTUNIDADES'],
#       dtype='object')

# %%
dados['QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?'].value_counts()
# Out:
# QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?
# Empregado (CLT)                                                    2762
# Empreendedor ou Empregado (CNPJ)                                    410
# Desempregado, buscando recolocação                                  350
# Estagiário                                                          188
# Servidor Público                                                    156
# Trabalho na área Acadêmica/Pesquisador                               86
# Somente Estudante (graduação)                                        82
# Vivo no Brasil e trabalho remoto para empresa de fora do Brasil      69
# Vivo fora do Brasil e trabalho para empresa de fora do Brasil        46
# Somente Estudante (pós-graduação)                                    44
# Freelancer                                                           39
# Prefiro não informar                                                 24
# Desempregado e não estou buscando recolocação                        15
# Name: count, dtype: int64

# %%
dados = dados[dados['QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?']=='Empregado (CLT)']

# %%
dados['QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?'].value_counts()
# Out:
# QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?
# Empregado (CLT)    2762
# Name: count, dtype: int64

# %%
dados['COR/RACA/ETNIA'].value_counts()
# Out:
# COR/RACA/ETNIA
# Branca                  1805
# Parda                    661
# Preta                    181
# Amarela                   85
# Prefiro não informar      16
# Outra                     10
# Indígena                   4
# Name: count, dtype: int64

# %%
lista_retirar = ['Prefiro não informar','Outra','Indígena']

# %%
dados[~dados['COR/RACA/ETNIA'].isin(lista_retirar)]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 6     zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# 7     zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34   Feminino
# ...                                ...    ...         ...        ...
# 4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
# 4263  02ido3x5siue5if02iz2taqjmcnh58xh   26.0       25-29  Masculino
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 1             Parda  Não  Sim, acredito que a minha a experiência profis...
# 2            Branca  Não                                                NaN
# 3            Branca  Não                                                NaN
# 6             Parda  Não  Não acredito que minha experiência profissiona...
# 7            Branca  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4262        Amarela  Não  Não acredito que minha experiência profissiona...
# 4263          Parda  Não  Sim, acredito que a minha a experiência profis...
# 4266         Branca  Não                                                NaN
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
# 4270         Branca  Não                                                NaN
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 1          Aprovação em processos seletivos/entrevistas            True
# 2                                                   NaN            True
# 3                                                   NaN            True
# 6                                                   NaN            True
# 7                                                   NaN            True
# ...                                                 ...             ...
# 4262                                                NaN            True
# 4263  Quantidade de oportunidades de emprego/vagas r...            True
# 4266                                                NaN            True
# 4267                                                NaN            True
# 4270                                                NaN            True
#
#             ESTADO ONDE MORA  ...  \
# 1                  Pará (PA)  ...
# 2      Distrito Federal (DF)  ...
# 3          Minas Gerais (MG)  ...
# 6             São Paulo (SP)  ...
# 7     Rio Grande do Sul (RS)  ...
# ...                      ...  ...
# 4262          São Paulo (SP)  ...
# 4263     Rio de Janeiro (RJ)  ...
# 4266          São Paulo (SP)  ...
# 4267       Minas Gerais (MG)  ...
# 4270              Goiás (GO)  ...
#
#      Você pretende mudar de emprego nos próximos 6 meses?  \
# 1     Estou em busca de oportunidades dentro ou fora...
# 2     Não estou buscando, mas me considero aberto a ...
# 3     Não estou buscando, mas me considero aberto a ...
# 6     Não estou buscando e não pretendo mudar de emp...
# 7     Estou em busca de oportunidades dentro ou fora...
# ...                                                 ...
# 4262  Não estou buscando, mas me considero aberto a ...
# 4263  Não estou buscando e não pretendo mudar de emp...
# 4266  Não estou buscando e não pretendo mudar de emp...
# 4267  Não estou buscando e não pretendo mudar de emp...
# 4270  Estou em busca de oportunidades dentro ou fora...
#
#      Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?  \
# 1     Remuneração/Salário, Plano de carreira e oport...
# 2     Remuneração/Salário, Flexibilidade de trabalho...
# 3     Remuneração/Salário, Flexibilidade de trabalho...
# 6     Oportunidade de aprendizado e trabalhar com re...
# 7     Remuneração/Salário, Propósito do trabalho e d...
# ...                                                 ...
# 4262  Remuneração/Salário, Flexibilidade de trabalho...
# 4263  Remuneração/Salário, Benefícios, Plano de carr...
# 4266  Remuneração/Salário, Benefícios, Flexibilidade...
# 4267  Ambiente e clima de trabalho, Plano de carreir...
# 4270  Remuneração/Salário, Oportunidade de aprendiza...
#
#                Atualmente qual a sua forma de trabalho?  \
# 1                                Modelo 100% presencial
# 2     Modelo híbrido com dias fixos de trabalho pres...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 6     Modelo híbrido com dias fixos de trabalho pres...
# 7                                Modelo 100% presencial
# ...                                                 ...
# 4262  Modelo híbrido flexível (o funcionário tem lib...
# 4263                                 Modelo 100% remoto
# 4266                                 Modelo 100% remoto
# 4267                                 Modelo 100% remoto
# 4270                                 Modelo 100% remoto
#
#               Qual a forma de trabalho ideal para você?  \
# 1     Modelo híbrido flexível (o funcionário tem lib...
# 2     Modelo híbrido flexível (o funcionário tem lib...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 6     Modelo híbrido flexível (o funcionário tem lib...
# 7                                    Modelo 100% remoto
# ...                                                 ...
# 4262  Modelo híbrido flexível (o funcionário tem lib...
# 4263  Modelo híbrido flexível (o funcionário tem lib...
# 4266  Modelo híbrido flexível (o funcionário tem lib...
# 4267  Modelo híbrido flexível (o funcionário tem lib...
# 4270                                 Modelo 100% remoto
#
#      Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 1      Vou aceitar e retornar ao modelo 100% presencial
# 2     Vou procurar outra oportunidade no modelo híbr...
# 3     Vou procurar outra oportunidade no modelo híbr...
# 6      Vou aceitar e retornar ao modelo 100% presencial
# 7     Vou procurar outra oportunidade no modelo 100%...
# ...                                                 ...
# 4262   Vou aceitar e retornar ao modelo 100% presencial
# 4263  Vou procurar outra oportunidade no modelo híbr...
# 4266  Vou procurar outra oportunidade no modelo híbr...
# 4267   Vou aceitar e retornar ao modelo 100% presencial
# 4270  Vou procurar outra oportunidade no modelo 100%...
#
#                   Sua empresa passu por Layoff em 2022?  \
# 1     Não ocorreram layoffs/demissões em massa na em...
# 2     Não ocorreram layoffs/demissões em massa na em...
# 3     Não ocorreram layoffs/demissões em massa na em...
# 6     Não ocorreram layoffs/demissões em massa na em...
# 7     Não ocorreram layoffs/demissões em massa na em...
# ...                                                 ...
# 4262  Não ocorreram layoffs/demissões em massa na em...
# 4263  Não ocorreram layoffs/demissões em massa na em...
# 4266  Não ocorreram layoffs/demissões em massa na em...
# 4267  Não ocorreram layoffs/demissões em massa na em...
# 4270  Não ocorreram layoffs/demissões em massa na em...
#
#                                                 Atuacao  \
# 1                                                Gestor
# 2     desenvolve modelos preditivos e algoritmos de ...
# 3     desenvolve modelos preditivos e algoritmos de ...
# 6                                      Análise de Dados
# 7                                         Outra atuação
# ...                                                 ...
# 4262                                             Gestor
# 4263                                Engenharia de Dados
# 4266                                   Análise de Dados
# 4267                                Engenharia de Dados
# 4270                                   Análise de Dados
#
#      Quais das linguagens listadas abaixo você utiliza no trabalho? EM_BUSCA  \
# 1                                                   NaN                  1.0
# 2                                                     1                  0.0
# 3                                                     0                  0.0
# 6                                SQL, Python, SAS/Stata                  0.0
# 7                                       SQL, JavaScript                  1.0
# ...                                                 ...                  ...
# 4262                                                NaN                  0.0
# 4263                                        Python, SQL                  0.0
# 4266                                                SQL                  0.0
# 4267                                        SQL, Python                  0.0
# 4270                                                SQL                  1.0
#
#       ABERTO_OPORTUNIDADES
# 1                      0.0
# 2                      1.0
# 3                      1.0
# 6                      0.0
# 7                      0.0
# ...                    ...
# 4262                   1.0
# 4263                   0.0
# 4266                   0.0
# 4267                   0.0
# 4270                   0.0
#
# [2732 rows x 46 columns]

# %%
dados['NAO_BRANCA'] = dados['COR/RACA/ETNIA'].apply(lambda x: 1 if x != 'Branca' else 0)

# %%
dados['QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?'].value_counts()
# Out:
# QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?
# de 1 a 2 anos                             752
# de 3 a 4 anos                             586
# de 4 a 6 anos                             423
# Menos de 1 ano                            358
# Mais de 10 anos                           281
# de 7 a 10 anos                            235
# Não tenho experiência na área de dados    127
# Name: count, dtype: int64

# %%
dados['TEMPO_EXPERIENCIA'] = dados['QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?'].str.extract(r'(\d+)')

# %%
dados['TEMPO_EXPERIENCIA'].value_counts()
# Out:
# TEMPO_EXPERIENCIA
# 1     1110
# 3      586
# 4      423
# 10     281
# 7      235
# Name: count, dtype: int64

# %%
dados['NUMERO DE FUNCIONARIOS'].value_counts()
# Out:
# NUMERO DE FUNCIONARIOS
# Acima de 3000     1325
# de 101 a 500       508
# de 1001 a 3000     371
# de 501 a 1000      251
# de 51 a 100        151
# de 11 a 50         114
# de 6 a 10           24
# de 1 a 5            18
# Name: count, dtype: int64

# %%
dados['NUMERO DE FUNCIONARIOS'] = dados['NUMERO DE FUNCIONARIOS'].str.replace('.','')

# %%
dados['NUMERO DE FUNCIONARIOS'] = dados['NUMERO DE FUNCIONARIOS'].str.extract(r'(\d+)')

# %%
dados['NUMERO DE FUNCIONARIOS'].value_counts(dropna=False)
# Out:
# NUMERO DE FUNCIONARIOS
# 3000    1325
# 101      508
# 1001     371
# 501      251
# 51       151
# 11       114
# 6         24
# 1         18
# Name: count, dtype: int64

# %%
dados['TEMPO_EXPERIENCIA'].value_counts(dropna=False)
# Out:
# TEMPO_EXPERIENCIA
# 1     1110
# 3      586
# 4      423
# 10     281
# 7      235
# 0      127
# Name: count, dtype: int64

# %%
dados['TEMPO_EXPERIENCIA'] = dados['TEMPO_EXPERIENCIA'].fillna(0)

# %%
dados['TEMPO_EXPERIENCIA'].value_counts()
# Out:
# TEMPO_EXPERIENCIA
# 1     1110
# 3      586
# 4      423
# 10     281
# 7      235
# 0      127
# Name: count, dtype: int64
