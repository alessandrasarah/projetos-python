# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandrasarah/projetos-python/blob/main/An%C3%A1lise_de_dados_biblioteca_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução
#
# Neste notebook, iremos explorar os dados coletados na pesquisa anual do Datahackers 2022. A pesquisa do Datahackers é uma fonte valiosa de informações sobre o mercado de trabalho na área de Tecnologia da Informação (TI) no Brasil, abordando uma ampla gama de tópicos relevantes para profissionais, empresas e instituições de ensino.
#
# A importância dessa pesquisa não pode ser subestimada, pois fornece insights cruciais sobre tendências, demandas e desafios enfrentados pelos profissionais de TI no Brasil. Além disso, a pesquisa contribui significativamente para o debate sobre diversidade no setor, incluindo questões de gênero, raça e outros aspectos relacionados à inclusão.
#
# O objetivo desta análise de dados é duplo: em primeiro lugar, buscamos aprender e praticar técnicas de análise de dados utilizando Python e bibliotecas como pandas, matplotblib e seaborn. Em segundo lugar, pretendemos extrair insights importantes sobre o mercado de trabalho na área de TI, identificando padrões, tendências e correlações nos dados coletados.
#
# Além de explorar aspectos como salários, níveis de escolaridade e tecnologias mais utilizadas, daremos um foco especial ao debate de diversidade, investigando questões de representatividade de gênero e raça no campo da tecnologia.
#
# Vamos começar nossa jornada de exploração dos dados e descobertas.

# %% [markdown]
# # Importações

# %%
#Importações:
from google.colab import drive
import pandas as pd

# %% [markdown]
# # Uso da biblioteca Pandas

# %%
#Montando o drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Lendo os dados
dados = pd.read_excel('/content/drive/MyDrive/Programaria/Cópia de [Copie essa planilha] planilha_modulo2.xlsx')

# %%
dados.head(10)
# Out:
#                                  ID  IDADE FAIXA IDADE     GENERO  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# 5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# 6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# 7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34   Feminino
# 8  zy4o5dk6iuxpdwgzy4o58xvd6ykwohrj   33.0       30-34  Masculino
# 9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
# 5          Parda  Não  Não acredito que minha experiência profissiona...
# 6          Parda  Não  Não acredito que minha experiência profissiona...
# 7         Branca  Não  Não acredito que minha experiência profissiona...
# 8         Branca  Não                                                NaN
# 9          Parda  Não  Não acredito que minha experiência profissiona...
#
#                           ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0                                           NaN            True
# 1  Aprovação em processos seletivos/entrevistas            True
# 2                                           NaN            True
# 3                                           NaN            True
# 4                                           NaN            True
# 5                                           NaN            True
# 6                                           NaN            True
# 7                                           NaN            True
# 8                                           NaN            True
# 9                                           NaN            True
#
#          ESTADO ONDE MORA  ... QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 0   Distrito Federal (DF)  ...                     Servidor Público
# 1               Pará (PA)  ...                      Empregado (CLT)
# 2   Distrito Federal (DF)  ...                      Empregado (CLT)
# 3       Minas Gerais (MG)  ...                      Empregado (CLT)
# 4               Pará (PA)  ...                     Servidor Público
# 5              Ceará (CE)  ...                     Servidor Público
# 6          São Paulo (SP)  ...                      Empregado (CLT)
# 7  Rio Grande do Sul (RS)  ...                      Empregado (CLT)
# 8          São Paulo (SP)  ...                      Empregado (CLT)
# 9              Bahia (BA)  ...                      Empregado (CLT)
#
#                             SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 0                   Setor Público         Acima de 3.000   False
# 1                     Outra Opção         Acima de 3.000    True
# 2              Finanças ou Bancos         Acima de 3.000   False
# 3                Setor Automotivo         Acima de 3.000   False
# 4                   Setor Público           de 101 a 500   False
# 5                        Educação         Acima de 3.000   False
# 6              Finanças ou Bancos         Acima de 3.000   False
# 7  Tecnologia/Fábrica de Software              de 6 a 10   False
# 8  Tecnologia/Fábrica de Software         Acima de 3.000   False
# 9                        Educação         Acima de 3.000   False
#
#         CARGO COMO GESTOR                                        CARGO ATUAL  \
# 0                     NaN                DBA/Administrador de Banco de Dados
# 1  Supervisor/Coordenador                                                NaN
# 2                     NaN  Desenvolvedor/ Engenheiro de Software/ Analist...
# 3                     NaN                  Cientista de Dados/Data Scientist
# 4                     NaN  Desenvolvedor/ Engenheiro de Software/ Analist...
# 5                     NaN                                          Professor
# 6                     NaN                          Analista de BI/BI Analyst
# 7                     NaN  Desenvolvedor/ Engenheiro de Software/ Analist...
# 8                     NaN                          Analista de BI/BI Analyst
# 9                     NaN                                          Professor
#
#     NIVEL                    FAIXA SALARIAL  \
# 0  Júnior   de R$ 8.001/mês a R$ 12.000/mês
# 1     NaN    de R$ 4.001/mês a R$ 6.000/mês
# 2   Pleno  de R$ 12.001/mês a R$ 16.000/mês
# 3  Sênior  de R$ 12.001/mês a R$ 16.000/mês
# 4   Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 5   Pleno    de R$ 2.001/mês a R$ 3.000/mês
# 6  Júnior    de R$ 4.001/mês a R$ 6.000/mês
# 7  Júnior    de R$ 2.001/mês a R$ 3.000/mês
# 8  Sênior    de R$ 6.001/mês a R$ 8.000/mês
# 9   Pleno   de R$ 8.001/mês a R$ 12.000/mês
#
#   QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
# 5             Não tenho experiência na área de dados
# 6                                      de 1 a 2 anos
# 7                                     Menos de 1 ano
# 8                                     Menos de 1 ano
# 9                                    Mais de 10 anos
#
#   QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
# 5  Não tive experiência na área de TI/Engenharia ...
# 6                                     Menos de 1 ano
# 7                                     Menos de 1 ano
# 8  Não tive experiência na área de TI/Engenharia ...
# 9  Não tive experiência na área de TI/Engenharia ...
#
# [10 rows x 26 columns]

# %%
dados.tail()
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4266         Branca  Não                                                NaN
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
# 4268         Branca  Não                                                NaN
# 4269         Branca  Não                                                NaN
# 4270         Branca  Não                                                NaN
#
#      ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL   ESTADO ONDE MORA  ...  \
# 4266                   NaN            True     São Paulo (SP)  ...
# 4267                   NaN            True  Minas Gerais (MG)  ...
# 4268                   NaN            True     São Paulo (SP)  ...
# 4269                   NaN            True     São Paulo (SP)  ...
# 4270                   NaN            True         Goiás (GO)  ...
#
#      QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 4266                      Empregado (CLT)
# 4267                      Empregado (CLT)
# 4268     Empreendedor ou Empregado (CNPJ)
# 4269                           Estagiário
# 4270                      Empregado (CLT)
#
#                                     SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 4266       Tecnologia/Fábrica de Software         Acima de 3.000   False
# 4267                  Área de Consultoria            de 51 a 100   False
# 4268  Setor Imobiliário/ Construção Civil           de 101 a 500    True
# 4269                            Indústria       de 1.001 a 3.000   False
# 4270                         Agronegócios         de 501 a 1.000   False
#
#      CARGO COMO GESTOR                                        CARGO ATUAL  \
# 4266               NaN                     Analista de Dados/Data Analyst
# 4267               NaN  Engenheiro de Dados/Arquiteto de Dados/Data En...
# 4268      Gerente/Head                                                NaN
# 4269               NaN                                        Outra Opção
# 4270               NaN                     Analista de Dados/Data Analyst
#
#        NIVEL                    FAIXA SALARIAL  \
# 4266   Pleno    de R$ 4.001/mês a R$ 6.000/mês
# 4267   Pleno    de R$ 3.001/mês a R$ 4.000/mês
# 4268     NaN  de R$ 16.001/mês a R$ 20.000/mês
# 4269  Júnior             Menos de R$ 1.000/mês
# 4270  Júnior    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4266                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
# 4268                                      de 4 a 6 anos
# 4269                                     Menos de 1 ano
# 4270                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4269  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
# [5 rows x 26 columns]

# %%
dados.shape
# Out:
# (4271, 26)

# %%
len(dados)
# Out:
# 4271

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 26 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   ID                                                                                                                         4271 non-null   object
#  1   IDADE                                                                                                                      4197 non-null   float64
#  2   FAIXA IDADE                                                                                                                4271 non-null   object
#  3   GENERO                                                                                                                     4262 non-null   object
#  4   COR/RACA/ETNIA                                                                                                             4271 non-null   object
#  5   PCD                                                                                                                        4271 non-null   object
#  6   EXPERIENCIA_PROFISSIONAL_PREJUDICADA                                                                                       2190 non-null   object
#  7   ASPECTOS_PREJUDICADOS                                                                                                      837 non-null    object
#  8   VIVE_NO_BRASIL                                                                                                             4271 non-null   bool
#  9   ESTADO ONDE MORA                                                                                                           4156 non-null   object
#  10  UF ONDE MORA                                                                                                               4156 non-null   object
#  11  REGIAO ONDE MORA                                                                                                           4171 non-null   object
#  12  MUDOU DE ESTADO?                                                                                                           4171 non-null   object
#  13  REGIAO DE ORIGEM                                                                                                           772 non-null    object
#  14  NIVEL DE ENSINO                                                                                                            4271 non-null   object
#  15  ÁREA DE FORMAÇÃO                                                                                                           4149 non-null   object
#  16  QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?                                                                                       4271 non-null   object
#  17  SETOR                                                                                                                      3694 non-null   object
#  18  NUMERO DE FUNCIONARIOS                                                                                                     3694 non-null   object
#  19  GESTOR?                                                                                                                    3694 non-null   object
#  20  CARGO COMO GESTOR                                                                                                          713 non-null    object
#  21  CARGO ATUAL                                                                                                                2981 non-null   object
#  22  NIVEL                                                                                                                      2981 non-null   object
#  23  FAIXA SALARIAL                                                                                                             3694 non-null   object
#  24  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?                                                                     3694 non-null   object
#  25  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  3694 non-null   object
# dtypes: bool(1), float64(1), object(24)
# memory usage: 838.5+ KB

# %%
dados.describe()
# Out:
#              IDADE
# count  4197.000000
# mean     31.169168
# std       6.902803
# min      18.000000
# 25%      26.000000
# 50%      30.000000
# 75%      35.000000
# max      54.000000

# %% [markdown]
# # Repetindo análise do excel

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?'],
#       dtype='object')

# %%
dados['GENERO']
# Out:
# 0       Masculino
# 1       Masculino
# 2       Masculino
# 3       Masculino
# 4        Feminino
#           ...
# 4266    Masculino
# 4267     Feminino
# 4268    Masculino
# 4269    Masculino
# 4270    Masculino
# Name: GENERO, Length: 4271, dtype: object

# %%
dados [dados['GENERO']=='Feminino']
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7     zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 9     zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+  Feminino
# 10    zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29  Feminino
# ...                                ...    ...         ...       ...
# 4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29  Feminino
# 4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
# 4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29  Feminino
# 4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29  Feminino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34  Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# 7            Branca  Não  Não acredito que minha experiência profissiona...
# 9             Parda  Não  Não acredito que minha experiência profissiona...
# 10            Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4248         Branca  Não  Não acredito que minha experiência profissiona...
# 4251          Preta  Não  Não acredito que minha experiência profissiona...
# 4258         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4259         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 4                                                   NaN            True
# 5                                                   NaN            True
# 7                                                   NaN            True
# 9                                                   NaN            True
# 10                                                  NaN            True
# ...                                                 ...             ...
# 4248                                                NaN            True
# 4251                                                NaN            True
# 4258  Senioridade das vagas recebidas em relação à s...            True
# 4259  Relação com outros membros da empresa, em mome...            True
# 4267                                                NaN            True
#
#             ESTADO ONDE MORA  ... QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 4                  Pará (PA)  ...                     Servidor Público
# 5                 Ceará (CE)  ...                     Servidor Público
# 7     Rio Grande do Sul (RS)  ...                      Empregado (CLT)
# 9                 Bahia (BA)  ...                      Empregado (CLT)
# 10       Rio de Janeiro (RJ)  ...                      Empregado (CLT)
# ...                      ...  ...                                  ...
# 4248  Rio Grande do Sul (RS)  ...                      Empregado (CLT)
# 4251       Minas Gerais (MG)  ...                      Empregado (CLT)
# 4258       Minas Gerais (MG)  ...    Somente Estudante (pós-graduação)
# 4259          São Paulo (SP)  ...                      Empregado (CLT)
# 4267       Minas Gerais (MG)  ...                      Empregado (CLT)
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 4                      Setor Público           de 101 a 500   False
# 5                           Educação         Acima de 3.000   False
# 7     Tecnologia/Fábrica de Software              de 6 a 10   False
# 9                           Educação         Acima de 3.000   False
# 10                            Varejo           de 101 a 500   False
# ...                              ...                    ...     ...
# 4248              Finanças ou Bancos           de 101 a 500   False
# 4251              Finanças ou Bancos       de 1.001 a 3.000   False
# 4258                             NaN                    NaN     NaN
# 4259              Finanças ou Bancos         Acima de 3.000    True
# 4267             Área de Consultoria            de 51 a 100   False
#
#            CARGO COMO GESTOR  \
# 4                        NaN
# 5                        NaN
# 7                        NaN
# 9                        NaN
# 10                       NaN
# ...                      ...
# 4248                     NaN
# 4251                     NaN
# 4258                     NaN
# 4259  Supervisor/Coordenador
# 4267                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...  Júnior
# 9                                             Professor   Pleno
# 10                            Analista de BI/BI Analyst  Júnior
# ...                                                 ...     ...
# 4248                  Cientista de Dados/Data Scientist   Pleno
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4258                                                NaN     NaN
# 4259                                                NaN     NaN
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
#
#                         FAIXA SALARIAL  \
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 7       de R$ 2.001/mês a R$ 3.000/mês
# 9      de R$ 8.001/mês a R$ 12.000/mês
# 10      de R$ 3.001/mês a R$ 4.000/mês
# ...                                ...
# 4248    de R$ 4.001/mês a R$ 6.000/mês
# 4251    de R$ 4.001/mês a R$ 6.000/mês
# 4258                               NaN
# 4259  de R$ 20.001/mês a R$ 25.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 9                                       Mais de 10 anos
# 10                                       Menos de 1 ano
# ...                                                 ...
# 4248                                      de 1 a 2 anos
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259                                      de 4 a 6 anos
# 4267                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 9     Não tive experiência na área de TI/Engenharia ...
# 10    Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4248  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259  Não tive experiência na área de TI/Engenharia ...
# 4267  Não tive experiência na área de TI/Engenharia ...
#
# [1056 rows x 26 columns]

# %%
dados[dados['GENERO']!="Masculino"]
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7     zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 9     zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+  Feminino
# 10    zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29  Feminino
# ...                                ...    ...         ...       ...
# 4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29  Feminino
# 4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
# 4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29  Feminino
# 4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29  Feminino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34  Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# 7            Branca  Não  Não acredito que minha experiência profissiona...
# 9             Parda  Não  Não acredito que minha experiência profissiona...
# 10            Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4248         Branca  Não  Não acredito que minha experiência profissiona...
# 4251          Preta  Não  Não acredito que minha experiência profissiona...
# 4258         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4259         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 4                                                   NaN            True
# 5                                                   NaN            True
# 7                                                   NaN            True
# 9                                                   NaN            True
# 10                                                  NaN            True
# ...                                                 ...             ...
# 4248                                                NaN            True
# 4251                                                NaN            True
# 4258  Senioridade das vagas recebidas em relação à s...            True
# 4259  Relação com outros membros da empresa, em mome...            True
# 4267                                                NaN            True
#
#             ESTADO ONDE MORA  ... QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 4                  Pará (PA)  ...                     Servidor Público
# 5                 Ceará (CE)  ...                     Servidor Público
# 7     Rio Grande do Sul (RS)  ...                      Empregado (CLT)
# 9                 Bahia (BA)  ...                      Empregado (CLT)
# 10       Rio de Janeiro (RJ)  ...                      Empregado (CLT)
# ...                      ...  ...                                  ...
# 4248  Rio Grande do Sul (RS)  ...                      Empregado (CLT)
# 4251       Minas Gerais (MG)  ...                      Empregado (CLT)
# 4258       Minas Gerais (MG)  ...    Somente Estudante (pós-graduação)
# 4259          São Paulo (SP)  ...                      Empregado (CLT)
# 4267       Minas Gerais (MG)  ...                      Empregado (CLT)
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 4                      Setor Público           de 101 a 500   False
# 5                           Educação         Acima de 3.000   False
# 7     Tecnologia/Fábrica de Software              de 6 a 10   False
# 9                           Educação         Acima de 3.000   False
# 10                            Varejo           de 101 a 500   False
# ...                              ...                    ...     ...
# 4248              Finanças ou Bancos           de 101 a 500   False
# 4251              Finanças ou Bancos       de 1.001 a 3.000   False
# 4258                             NaN                    NaN     NaN
# 4259              Finanças ou Bancos         Acima de 3.000    True
# 4267             Área de Consultoria            de 51 a 100   False
#
#            CARGO COMO GESTOR  \
# 4                        NaN
# 5                        NaN
# 7                        NaN
# 9                        NaN
# 10                       NaN
# ...                      ...
# 4248                     NaN
# 4251                     NaN
# 4258                     NaN
# 4259  Supervisor/Coordenador
# 4267                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...  Júnior
# 9                                             Professor   Pleno
# 10                            Analista de BI/BI Analyst  Júnior
# ...                                                 ...     ...
# 4248                  Cientista de Dados/Data Scientist   Pleno
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4258                                                NaN     NaN
# 4259                                                NaN     NaN
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
#
#                         FAIXA SALARIAL  \
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 7       de R$ 2.001/mês a R$ 3.000/mês
# 9      de R$ 8.001/mês a R$ 12.000/mês
# 10      de R$ 3.001/mês a R$ 4.000/mês
# ...                                ...
# 4248    de R$ 4.001/mês a R$ 6.000/mês
# 4251    de R$ 4.001/mês a R$ 6.000/mês
# 4258                               NaN
# 4259  de R$ 20.001/mês a R$ 25.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 9                                       Mais de 10 anos
# 10                                       Menos de 1 ano
# ...                                                 ...
# 4248                                      de 1 a 2 anos
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259                                      de 4 a 6 anos
# 4267                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 9     Não tive experiência na área de TI/Engenharia ...
# 10    Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4248  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
# 4258                                                NaN
# 4259  Não tive experiência na área de TI/Engenharia ...
# 4267  Não tive experiência na área de TI/Engenharia ...
#
# [1077 rows x 26 columns]

# %%
dados[dados['GENERO'].str.contains('não', na=False)]
# Out:
#                                     ID  IDADE FAIXA IDADE  \
# 562   vhuw8xnpbmj6oh20xovhuwcbdl4a12ni   29.0       25-29
# 1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1    NaN         55+
# 1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19   30.0       30-34
# 1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2554  f5l206z0hr9uh3nz2iiff5l206c0g10o   20.0       17-21
# 3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o   26.0       25-29
# 3357  7q0icczxn0l3a894cbx7q0icczjyud0n   29.0       25-29
# 3493  6m8haop6lxnaizpwij6m8haopiax98jg   25.0       25-29
# 3610  5mloglozmr0r715mntaxbt6xy8b5olmb   30.0       30-34
# 4171  0rksyxnqhn13nwytwi6y0rkssx6jmodf   26.0       25-29
# 4200  0liu228yff8fnm3zeuahsx0liu228y07   28.0       25-29
# 4227  0eqzo5w2l5wizswvwywt8h0eqzo5yucv   28.0       25-29
#
#                     GENERO        COR/RACA/ETNIA                   PCD  \
# 562   Prefiro não informar                 Parda                   Não
# 1528  Prefiro não informar              Indígena  Prefiro não informar
# 1913  Prefiro não informar  Prefiro não informar                   Não
# 1925  Prefiro não informar  Prefiro não informar  Prefiro não informar
# 2554  Prefiro não informar  Prefiro não informar                   Não
# 3090  Prefiro não informar                 Parda                   Não
# 3357  Prefiro não informar                 Preta                   Não
# 3493  Prefiro não informar                Branca                   Não
# 3610  Prefiro não informar                Branca                   Não
# 4171  Prefiro não informar                Branca                   Não
# 4200  Prefiro não informar                 Outra                   Não
# 4227  Prefiro não informar                 Preta                   Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 562   Sim, acredito que a minha a experiência profis...
# 1528  Não acredito que minha experiência profissiona...
# 1913  Não acredito que minha experiência profissiona...
# 1925  Sim, acredito que minha experiência profission...
# 2554  Não acredito que minha experiência profissiona...
# 3090  Não acredito que minha experiência profissiona...
# 3357  Não acredito que minha experiência profissiona...
# 3493  Sim, acredito que a minha a experiência profis...
# 3610  Sim, acredito que a minha a experiência profis...
# 4171  Não acredito que minha experiência profissiona...
# 4200  Não acredito que minha experiência profissiona...
# 4227  Sim, acredito que a minha a experiência profis...
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 562   Atenção dada pelas pessoas diante das minhas o...            True
# 1528                                                NaN            True
# 1913                                                NaN            True
# 1925  Quantidade de oportunidades de emprego/vagas r...           False
# 2554                                                NaN            True
# 3090                                                NaN            True
# 3357                                                NaN            True
# 3493  Quantidade de oportunidades de emprego/vagas r...            True
# 3610               Velocidade de progressão de carreira            True
# 4171                                                NaN            True
# 4200                                                NaN            True
# 4227  Atenção dada pelas pessoas diante das minhas o...            True
#
#               ESTADO ONDE MORA  ...  \
# 562             São Paulo (SP)  ...
# 1528                       NaN  ...
# 1913            São Paulo (SP)  ...
# 1925                       NaN  ...
# 2554     Distrito Federal (DF)  ...
# 3090  Rio Grande do Norte (RN)  ...
# 3357       Rio de Janeiro (RJ)  ...
# 3493            São Paulo (SP)  ...
# 3610            São Paulo (SP)  ...
# 4171            São Paulo (SP)  ...
# 4200            São Paulo (SP)  ...
# 4227            São Paulo (SP)  ...
#
#                QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 562   Desempregado e não estou buscando recolocação
# 1528                                     Estagiário
# 1913                           Prefiro não informar
# 1925                           Prefiro não informar
# 2554                                     Estagiário
# 3090                                Empregado (CLT)
# 3357                                Empregado (CLT)
# 3493                                Empregado (CLT)
# 3610                                Empregado (CLT)
# 4171                                Empregado (CLT)
# 4200                                Empregado (CLT)
# 4227                                Empregado (CLT)
#
#                                     SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 562                                   NaN                    NaN     NaN
# 1528                        Setor Público            de 51 a 100   False
# 1913                          Outra Opção           de 101 a 500   False
# 1925                   Setor Farmaceutico               de 1 a 5   False
# 2554                        Setor Público         Acima de 3.000   False
# 3090                             Educação           de 101 a 500    True
# 3357       Tecnologia/Fábrica de Software       de 1.001 a 3.000   False
# 3493                   Finanças ou Bancos         Acima de 3.000   False
# 3610       Tecnologia/Fábrica de Software           de 101 a 500   False
# 4171                          Outra Opção       de 1.001 a 3.000   False
# 4200  Setor Imobiliário/ Construção Civil         de 501 a 1.000    True
# 4227                          Outra Opção         Acima de 3.000   False
#
#             CARGO COMO GESTOR  \
# 562                       NaN
# 1528                      NaN
# 1913                      NaN
# 1925                      NaN
# 2554                      NaN
# 3090  Team Leader/Tech Leader
# 3357                      NaN
# 3493                      NaN
# 3610                      NaN
# 4171                      NaN
# 4200  Team Leader/Tech Leader
# 4227                      NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 562                                                 NaN     NaN
# 1528               Analista de Suporte/Analista Técnico  Júnior
# 1913                     Analista de Dados/Data Analyst   Pleno
# 1925                                        Outra Opção  Júnior
# 2554                  Cientista de Dados/Data Scientist  Júnior
# 3090                                                NaN     NaN
# 3357  Engenheiro de Dados/Arquiteto de Dados/Data En...  Júnior
# 3493                     Analista de Dados/Data Analyst   Pleno
# 3610  Engenheiro de Dados/Arquiteto de Dados/Data En...  Sênior
# 4171                     Analista de Dados/Data Analyst   Pleno
# 4200                                                NaN     NaN
# 4227  Product Manager/ Product Owner (PM/APM/DPM/GPM...   Pleno
#
#                         FAIXA SALARIAL  \
# 562                                NaN
# 1528             Menos de R$ 1.000/mês
# 1913   de R$ 8.001/mês a R$ 12.000/mês
# 1925    de R$ 2.001/mês a R$ 3.000/mês
# 2554    de R$ 1.001/mês a R$ 2.000/mês
# 3090   de R$ 8.001/mês a R$ 12.000/mês
# 3357    de R$ 6.001/mês a R$ 8.000/mês
# 3493    de R$ 3.001/mês a R$ 4.000/mês
# 3610   de R$ 8.001/mês a R$ 12.000/mês
# 4171   de R$ 8.001/mês a R$ 12.000/mês
# 4200  de R$ 16.001/mês a R$ 20.000/mês
# 4227    de R$ 6.001/mês a R$ 8.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 562                                                 NaN
# 1528                                     Menos de 1 ano
# 1913                                    Mais de 10 anos
# 1925                                      de 1 a 2 anos
# 2554                                      de 1 a 2 anos
# 3090                                      de 1 a 2 anos
# 3357                                     Menos de 1 ano
# 3493                                      de 3 a 4 anos
# 3610                                      de 3 a 4 anos
# 4171                                      de 1 a 2 anos
# 4200                                    Mais de 10 anos
# 4227                                     Menos de 1 ano
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 562                                                 NaN
# 1528                                     Menos de 1 ano
# 1913                                      de 3 a 4 anos
# 1925                                     Menos de 1 ano
# 2554                                      de 1 a 2 anos
# 3090  Não tive experiência na área de TI/Engenharia ...
# 3357  Não tive experiência na área de TI/Engenharia ...
# 3493                                     Menos de 1 ano
# 3610  Não tive experiência na área de TI/Engenharia ...
# 4171                                     Menos de 1 ano
# 4200                                     de 7 a 10 anos
# 4227  Não tive experiência na área de TI/Engenharia ...
#
# [12 rows x 26 columns]

# %%
dados[dados['IDADE']>=30]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# ...                                ...    ...         ...        ...
# 4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39  Masculino
# 4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34  Masculino
# 4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
# 4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39  Masculino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0             Parda  Não  Não acredito que minha experiência profissiona...
# 1             Parda  Não  Sim, acredito que a minha a experiência profis...
# 2            Branca  Não                                                NaN
# 4            Branca  Não  Não acredito que minha experiência profissiona...
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4260          Parda  Não  Não acredito que minha experiência profissiona...
# 4261         Branca  Não                                                NaN
# 4262        Amarela  Não  Não acredito que minha experiência profissiona...
# 4264         Branca  Não                                                NaN
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
#
#                              ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0                                              NaN            True
# 1     Aprovação em processos seletivos/entrevistas            True
# 2                                              NaN            True
# 4                                              NaN            True
# 5                                              NaN            True
# ...                                            ...             ...
# 4260                                           NaN            True
# 4261                                           NaN            True
# 4262                                           NaN            True
# 4264                                           NaN            True
# 4267                                           NaN            True
#
#             ESTADO ONDE MORA  ... QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 0      Distrito Federal (DF)  ...                     Servidor Público
# 1                  Pará (PA)  ...                      Empregado (CLT)
# 2      Distrito Federal (DF)  ...                      Empregado (CLT)
# 4                  Pará (PA)  ...                     Servidor Público
# 5                 Ceará (CE)  ...                     Servidor Público
# ...                      ...  ...                                  ...
# 4260              Piauí (PI)  ...   Desempregado, buscando recolocação
# 4261  Rio Grande do Sul (RS)  ...   Desempregado, buscando recolocação
# 4262          São Paulo (SP)  ...                      Empregado (CLT)
# 4264          São Paulo (SP)  ...     Empreendedor ou Empregado (CNPJ)
# 4267       Minas Gerais (MG)  ...                      Empregado (CLT)
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 0                      Setor Público         Acima de 3.000   False
# 1                        Outra Opção         Acima de 3.000    True
# 2                 Finanças ou Bancos         Acima de 3.000   False
# 4                      Setor Público           de 101 a 500   False
# 5                           Educação         Acima de 3.000   False
# ...                              ...                    ...     ...
# 4260                             NaN                    NaN     NaN
# 4261                             NaN                    NaN     NaN
# 4262  Tecnologia/Fábrica de Software         de 501 a 1.000    True
# 4264  Tecnologia/Fábrica de Software            de 51 a 100    True
# 4267             Área de Consultoria            de 51 a 100   False
#
#             CARGO COMO GESTOR  \
# 0                         NaN
# 1      Supervisor/Coordenador
# 2                         NaN
# 4                         NaN
# 5                         NaN
# ...                       ...
# 4260                      NaN
# 4261                      NaN
# 4262  Team Leader/Tech Leader
# 4264             Gerente/Head
# 4267                      NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 0                   DBA/Administrador de Banco de Dados  Júnior
# 1                                                   NaN     NaN
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# ...                                                 ...     ...
# 4260                                                NaN     NaN
# 4261                                                NaN     NaN
# 4262                                                NaN     NaN
# 4264                                                NaN     NaN
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
#
#                         FAIXA SALARIAL  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 1       de R$ 4.001/mês a R$ 6.000/mês
# 2     de R$ 12.001/mês a R$ 16.000/mês
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# ...                                ...
# 4260                               NaN
# 4261                               NaN
# 4262  de R$ 16.001/mês a R$ 20.000/mês
# 4264  de R$ 20.001/mês a R$ 25.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 2                                         de 3 a 4 anos
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# ...                                                 ...
# 4260                                                NaN
# 4261                                                NaN
# 4262                                      de 3 a 4 anos
# 4264                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 2                                       Mais de 10 anos
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4260                                                NaN
# 4261                                                NaN
# 4262                                      de 3 a 4 anos
# 4264                                    Mais de 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
#
# [2204 rows x 26 columns]

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')]
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7     zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 14    zwez49k0jhdvfkfst4zwef137uuf4ivy   35.0       35-39  Feminino
# 23    zuqfcwtl9unfc5ezuqfcwm8coytsp5ap   46.0       45-49  Feminino
# ...                                ...    ...         ...       ...
# 4214  0gprow0ownrbfneftxf0gprow4kyrqdy   41.0       40-44  Feminino
# 4221  0fgi5bnb0u9b0fgc0jmqlbnvtu12b76d   34.0       30-34  Feminino
# 4240  0a5xgxb1ljmuqn0un8a10a5xg4eufs2l   37.0       35-39  Feminino
# 4247  07qzabp4ujpe4oz81udmb07qzabp4h0t   34.0       30-34  Feminino
# 4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
#
#      COR/RACA/ETNIA                   PCD  \
# 4            Branca                   Não
# 5             Parda                   Não
# 7            Branca                   Não
# 14            Parda                   Não
# 23           Branca                   Não
# ...             ...                   ...
# 4214         Branca  Prefiro não informar
# 4221          Outra                   Não
# 4240         Branca                   Não
# 4247         Branca                   Não
# 4251          Preta                   Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4     Não acredito que minha experiência profissiona...
# 5     Não acredito que minha experiência profissiona...
# 7     Não acredito que minha experiência profissiona...
# 14    Sim, acredito que a minha a experiência profis...
# 23    Não acredito que minha experiência profissiona...
# ...                                                 ...
# 4214  Sim, acredito que a minha a experiência profis...
# 4221  Não acredito que minha experiência profissiona...
# 4240  Sim, acredito que a minha a experiência profis...
# 4247  Não acredito que minha experiência profissiona...
# 4251  Não acredito que minha experiência profissiona...
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 4                                                   NaN            True
# 5                                                   NaN            True
# 7                                                   NaN            True
# 14    Atenção dada pelas pessoas diante das minhas o...            True
# 23                                                  NaN            True
# ...                                                 ...             ...
# 4214  Oportunidades de progressão de carreira, Veloc...            True
# 4221                                                NaN            True
# 4240  Quantidade de oportunidades de emprego/vagas r...            True
# 4247                                                NaN            True
# 4251                                                NaN            True
#
#             ESTADO ONDE MORA  ... QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 4                  Pará (PA)  ...                     Servidor Público
# 5                 Ceará (CE)  ...                     Servidor Público
# 7     Rio Grande do Sul (RS)  ...                      Empregado (CLT)
# 14            São Paulo (SP)  ...                      Empregado (CLT)
# 23       Rio de Janeiro (RJ)  ...     Empreendedor ou Empregado (CNPJ)
# ...                      ...  ...                                  ...
# 4214          São Paulo (SP)  ...                      Empregado (CLT)
# 4221   Distrito Federal (DF)  ...                      Empregado (CLT)
# 4240            Sergipe (SE)  ...                      Empregado (CLT)
# 4247              Ceará (CE)  ...                      Empregado (CLT)
# 4251       Minas Gerais (MG)  ...                      Empregado (CLT)
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 4                      Setor Público           de 101 a 500   False
# 5                           Educação         Acima de 3.000   False
# 7     Tecnologia/Fábrica de Software              de 6 a 10   False
# 14                            Varejo         Acima de 3.000   False
# 23    Tecnologia/Fábrica de Software         de 501 a 1.000   False
# ...                              ...                    ...     ...
# 4214          Seguros ou Previdência         Acima de 3.000    True
# 4221             Área de Consultoria            de 51 a 100   False
# 4240              Finanças ou Bancos            de 51 a 100   False
# 4247                Setor de Energia             de 11 a 50   False
# 4251              Finanças ou Bancos       de 1.001 a 3.000   False
#
#            CARGO COMO GESTOR  \
# 4                        NaN
# 5                        NaN
# 7                        NaN
# 14                       NaN
# 23                       NaN
# ...                      ...
# 4214  Supervisor/Coordenador
# 4221                     NaN
# 4240                     NaN
# 4247                     NaN
# 4251                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# 7     Desenvolvedor/ Engenheiro de Software/ Analist...  Júnior
# 14                Analista de Negócios/Business Analyst   Pleno
# 23    Engenheiro de Dados/Arquiteto de Dados/Data En...  Sênior
# ...                                                 ...     ...
# 4214                                                NaN     NaN
# 4221                                        Outra Opção  Júnior
# 4240                          Analista de BI/BI Analyst  Júnior
# 4247                  Cientista de Dados/Data Scientist  Júnior
# 4251  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
#
#                         FAIXA SALARIAL  \
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 7       de R$ 2.001/mês a R$ 3.000/mês
# 14      de R$ 6.001/mês a R$ 8.000/mês
# 23    de R$ 12.001/mês a R$ 16.000/mês
# ...                                ...
# 4214   de R$ 8.001/mês a R$ 12.000/mês
# 4221    de R$ 4.001/mês a R$ 6.000/mês
# 4240    de R$ 1.001/mês a R$ 2.000/mês
# 4247    de R$ 4.001/mês a R$ 6.000/mês
# 4251    de R$ 4.001/mês a R$ 6.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 4                Não tenho experiência na área de dados
# 5                Não tenho experiência na área de dados
# 7                                        Menos de 1 ano
# 14                                        de 1 a 2 anos
# 23                                      Mais de 10 anos
# ...                                                 ...
# 4214                                      de 4 a 6 anos
# 4221                                     Menos de 1 ano
# 4240                                      de 1 a 2 anos
# 4247                                    Mais de 10 anos
# 4251                                     Menos de 1 ano
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# 7                                        Menos de 1 ano
# 14    Não tive experiência na área de TI/Engenharia ...
# 23                                        de 5 a 6 anos
# ...                                                 ...
# 4214  Não tive experiência na área de TI/Engenharia ...
# 4221                                     Menos de 1 ano
# 4240                                     Menos de 1 ano
# 4247  Não tive experiência na área de TI/Engenharia ...
# 4251                                     Menos de 1 ano
#
# [503 rows x 26 columns]

# %%
dados[dados['COR/RACA/ETNIA']=="Parda"]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# 6     zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# 9     zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+   Feminino
# ...                                ...    ...         ...        ...
# 4246  07zvu9j5tzsvwax518zelk07zvu9rq7y   33.0       30-34  Masculino
# 4252  064pe9b1htw7mflhif064pe95dotv6yf   39.0       35-39  Masculino
# 4256  04gb9ekqsw14vtkr5rpux04gb9evsfgq   28.0       25-29  Masculino
# 4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39  Masculino
# 4263  02ido3x5siue5if02iz2taqjmcnh58xh   26.0       25-29  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0             Parda  Não  Não acredito que minha experiência profissiona...
# 1             Parda  Não  Sim, acredito que a minha a experiência profis...
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# 6             Parda  Não  Não acredito que minha experiência profissiona...
# 9             Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4246          Parda  Não  Não acredito que minha experiência profissiona...
# 4252          Parda  Não  Não acredito que minha experiência profissiona...
# 4256          Parda  Não  Não acredito que minha experiência profissiona...
# 4260          Parda  Não  Não acredito que minha experiência profissiona...
# 4263          Parda  Não  Sim, acredito que a minha a experiência profis...
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0                                                   NaN            True
# 1          Aprovação em processos seletivos/entrevistas            True
# 5                                                   NaN            True
# 6                                                   NaN            True
# 9                                                   NaN            True
# ...                                                 ...             ...
# 4246                                                NaN            True
# 4252                                                NaN            True
# 4256                                                NaN            True
# 4260                                                NaN            True
# 4263  Quantidade de oportunidades de emprego/vagas r...            True
#
#            ESTADO ONDE MORA  ... QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 0     Distrito Federal (DF)  ...                     Servidor Público
# 1                 Pará (PA)  ...                      Empregado (CLT)
# 5                Ceará (CE)  ...                     Servidor Público
# 6            São Paulo (SP)  ...                      Empregado (CLT)
# 9                Bahia (BA)  ...                      Empregado (CLT)
# ...                     ...  ...                                  ...
# 4246         São Paulo (SP)  ...                      Empregado (CLT)
# 4252         São Paulo (SP)  ...        Somente Estudante (graduação)
# 4256    Rio de Janeiro (RJ)  ...                      Empregado (CLT)
# 4260             Piauí (PI)  ...   Desempregado, buscando recolocação
# 4263    Rio de Janeiro (RJ)  ...                      Empregado (CLT)
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 0                      Setor Público         Acima de 3.000   False
# 1                        Outra Opção         Acima de 3.000    True
# 5                           Educação         Acima de 3.000   False
# 6                 Finanças ou Bancos         Acima de 3.000   False
# 9                           Educação         Acima de 3.000   False
# ...                              ...                    ...     ...
# 4246                          Varejo         Acima de 3.000   False
# 4252                             NaN                    NaN     NaN
# 4256              Finanças ou Bancos         de 501 a 1.000   False
# 4260                             NaN                    NaN     NaN
# 4263  Tecnologia/Fábrica de Software         de 501 a 1.000   False
#
#            CARGO COMO GESTOR  \
# 0                        NaN
# 1     Supervisor/Coordenador
# 5                        NaN
# 6                        NaN
# 9                        NaN
# ...                      ...
# 4246                     NaN
# 4252                     NaN
# 4256                     NaN
# 4260                     NaN
# 4263                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 0                   DBA/Administrador de Banco de Dados  Júnior
# 1                                                   NaN     NaN
# 5                                             Professor   Pleno
# 6                             Analista de BI/BI Analyst  Júnior
# 9                                             Professor   Pleno
# ...                                                 ...     ...
# 4246              Analista de Negócios/Business Analyst  Sênior
# 4252                                                NaN     NaN
# 4256              Analista de Negócios/Business Analyst   Pleno
# 4260                                                NaN     NaN
# 4263  Engenheiro de Dados/Arquiteto de Dados/Data En...  Júnior
#
#                        FAIXA SALARIAL  \
# 0     de R$ 8.001/mês a R$ 12.000/mês
# 1      de R$ 4.001/mês a R$ 6.000/mês
# 5      de R$ 2.001/mês a R$ 3.000/mês
# 6      de R$ 4.001/mês a R$ 6.000/mês
# 9     de R$ 8.001/mês a R$ 12.000/mês
# ...                               ...
# 4246  de R$ 8.001/mês a R$ 12.000/mês
# 4252                              NaN
# 4256   de R$ 4.001/mês a R$ 6.000/mês
# 4260                              NaN
# 4263   de R$ 6.001/mês a R$ 8.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 5                Não tenho experiência na área de dados
# 6                                         de 1 a 2 anos
# 9                                       Mais de 10 anos
# ...                                                 ...
# 4246                                      de 3 a 4 anos
# 4252                                                NaN
# 4256                                      de 3 a 4 anos
# 4260                                                NaN
# 4263                                      de 3 a 4 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 5     Não tive experiência na área de TI/Engenharia ...
# 6                                        Menos de 1 ano
# 9     Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4246                                      de 5 a 6 anos
# 4252                                                NaN
# 4256  Não tive experiência na área de TI/Engenharia ...
# 4260                                                NaN
# 4263  Não tive experiência na área de TI/Engenharia ...
#
# [1054 rows x 26 columns]

# %%
dados[dados['IDADE']<=40]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 5     zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# 6     zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# ...                                ...    ...         ...        ...
# 4265  01nmlhyw8w2b4stchg01nmlvlcqp0iis   28.0       25-29  Masculino
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0             Parda  Não  Não acredito que minha experiência profissiona...
# 1             Parda  Não  Sim, acredito que a minha a experiência profis...
# 3            Branca  Não                                                NaN
# 5             Parda  Não  Não acredito que minha experiência profissiona...
# 6             Parda  Não  Não acredito que minha experiência profissiona...
# ...             ...  ...                                                ...
# 4265         Branca  Não                                                NaN
# 4266         Branca  Não                                                NaN
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
# 4268         Branca  Não                                                NaN
# 4270         Branca  Não                                                NaN
#
#                              ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0                                              NaN            True
# 1     Aprovação em processos seletivos/entrevistas            True
# 3                                              NaN            True
# 5                                              NaN            True
# 6                                              NaN            True
# ...                                            ...             ...
# 4265                                           NaN            True
# 4266                                           NaN            True
# 4267                                           NaN            True
# 4268                                           NaN            True
# 4270                                           NaN            True
#
#            ESTADO ONDE MORA  ... QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 0     Distrito Federal (DF)  ...                     Servidor Público
# 1                 Pará (PA)  ...                      Empregado (CLT)
# 3         Minas Gerais (MG)  ...                      Empregado (CLT)
# 5                Ceará (CE)  ...                     Servidor Público
# 6            São Paulo (SP)  ...                      Empregado (CLT)
# ...                     ...  ...                                  ...
# 4265            Paraná (PR)  ...     Empreendedor ou Empregado (CNPJ)
# 4266         São Paulo (SP)  ...                      Empregado (CLT)
# 4267      Minas Gerais (MG)  ...                      Empregado (CLT)
# 4268         São Paulo (SP)  ...     Empreendedor ou Empregado (CNPJ)
# 4270             Goiás (GO)  ...                      Empregado (CLT)
#
#                                     SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 0                           Setor Público         Acima de 3.000   False
# 1                             Outra Opção         Acima de 3.000    True
# 3                        Setor Automotivo         Acima de 3.000   False
# 5                                Educação         Acima de 3.000   False
# 6                      Finanças ou Bancos         Acima de 3.000   False
# ...                                   ...                    ...     ...
# 4265                            Marketing               de 1 a 5   False
# 4266       Tecnologia/Fábrica de Software         Acima de 3.000   False
# 4267                  Área de Consultoria            de 51 a 100   False
# 4268  Setor Imobiliário/ Construção Civil           de 101 a 500    True
# 4270                         Agronegócios         de 501 a 1.000   False
#
#            CARGO COMO GESTOR  \
# 0                        NaN
# 1     Supervisor/Coordenador
# 3                        NaN
# 5                        NaN
# 6                        NaN
# ...                      ...
# 4265                     NaN
# 4266                     NaN
# 4267                     NaN
# 4268            Gerente/Head
# 4270                     NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 0                   DBA/Administrador de Banco de Dados  Júnior
# 1                                                   NaN     NaN
# 3                     Cientista de Dados/Data Scientist  Sênior
# 5                                             Professor   Pleno
# 6                             Analista de BI/BI Analyst  Júnior
# ...                                                 ...     ...
# 4265                              Analista de Marketing   Pleno
# 4266                     Analista de Dados/Data Analyst   Pleno
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4268                                                NaN     NaN
# 4270                     Analista de Dados/Data Analyst  Júnior
#
#                         FAIXA SALARIAL  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 1       de R$ 4.001/mês a R$ 6.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# 6       de R$ 4.001/mês a R$ 6.000/mês
# ...                                ...
# 4265    de R$ 2.001/mês a R$ 3.000/mês
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4268  de R$ 16.001/mês a R$ 20.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 3                                         de 4 a 6 anos
# 5                Não tenho experiência na área de dados
# 6                                         de 1 a 2 anos
# ...                                                 ...
# 4265                                      de 3 a 4 anos
# 4266                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
# 4268                                      de 4 a 6 anos
# 4270                                      de 1 a 2 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 3     Não tive experiência na área de TI/Engenharia ...
# 5     Não tive experiência na área de TI/Engenharia ...
# 6                                        Menos de 1 ano
# ...                                                 ...
# 4265                                      de 1 a 2 anos
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
# [3753 rows x 26 columns]

# %%
dados.groupby('GENERO')['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# Name: ID, dtype: int64

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados['GENERO'].value_counts(dropna=False)
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      12
# NaN                        9
# Name: count, dtype: int64

# %%
dados[dados['IDADE']>30]['NIVEL'].value_counts()
# Out:
# NIVEL
# Sênior    525
# Pleno     408
# Júnior    274
# Name: count, dtype: int64

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')]['NIVEL'].value_counts()
# Out:
# NIVEL
# Pleno     117
# Sênior    114
# Júnior     96
# Name: count, dtype: int64

# %%
pd.pivot_table(dados, values=["ID"], index=['GENERO'], columns=['GESTOR?'], aggfunc='count')
# Out:
#                         ID
# GESTOR?              False True
# GENERO
# Feminino               754   132
# Masculino             2212   578
# Prefiro não informar     9     2

# %% [markdown]
# # Estatistica Básica

# %%
import numpy as np

# %%
lista_idades =[26, 30, 32, 22, 26, 35, 40, 20, 43, 31, 23]

# %%
np.sum(lista_idades)
# Out:
# np.int64(328)

# %%
len(lista_idades)
# Out:
# 11

# %%
np.sum(lista_idades)/len(lista_idades)
# Out:
# np.float64(29.818181818181817)

# %%
media = np.mean(lista_idades)
print('Media aritmetica:', media)
# Out:
# Media aritmetica: 29.818181818181817

# %%
#Colocando as idades na ordem:
lista_idades.sort()
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43]

# %%
lista_idades =[26, 30, 32, 22, 26, 35, 40, 20, 43, 31, 23,100]

# %%
lista_idades.sort()
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43, 100]

# %%
mediana = np.median(lista_idades)
mediana
# Out:
# np.float64(30.5)

# %% [markdown]
# #### Voltando para a tabela

# %%
dados['IDADE'].mean()
# Out:
# np.float64(31.169168453657374)

# %%
dados['IDADE'].median()
# Out:
# 30.0

# %%
dados['IDADE'].mode()
# Out:
# 0    27.0
# Name: IDADE, dtype: float64

# %%
dados['IDADE'].std()
# Out:
# 6.902802832143141

# %%
dados['IDADE'].min()
# Out:
# 18.0

# %%
dados['IDADE'].max()
# Out:
# 54.0

# %%
dados[dados['GENERO']=='Feminino']['IDADE'].mean()
# Out:
# np.float64(31.318051575931232)

# %% [markdown]
# # Valores faltantes

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 26 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   ID                                                                                                                         4271 non-null   object
#  1   IDADE                                                                                                                      4197 non-null   float64
#  2   FAIXA IDADE                                                                                                                4271 non-null   object
#  3   GENERO                                                                                                                     4262 non-null   object
#  4   COR/RACA/ETNIA                                                                                                             4271 non-null   object
#  5   PCD                                                                                                                        4271 non-null   object
#  6   EXPERIENCIA_PROFISSIONAL_PREJUDICADA                                                                                       2190 non-null   object
#  7   ASPECTOS_PREJUDICADOS                                                                                                      837 non-null    object
#  8   VIVE_NO_BRASIL                                                                                                             4271 non-null   bool
#  9   ESTADO ONDE MORA                                                                                                           4156 non-null   object
#  10  UF ONDE MORA                                                                                                               4156 non-null   object
#  11  REGIAO ONDE MORA                                                                                                           4171 non-null   object
#  12  MUDOU DE ESTADO?                                                                                                           4171 non-null   object
#  13  REGIAO DE ORIGEM                                                                                                           772 non-null    object
#  14  NIVEL DE ENSINO                                                                                                            4271 non-null   object
#  15  ÁREA DE FORMAÇÃO                                                                                                           4149 non-null   object
#  16  QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?                                                                                       4271 non-null   object
#  17  SETOR                                                                                                                      3694 non-null   object
#  18  NUMERO DE FUNCIONARIOS                                                                                                     3694 non-null   object
#  19  GESTOR?                                                                                                                    3694 non-null   object
#  20  CARGO COMO GESTOR                                                                                                          713 non-null    object
#  21  CARGO ATUAL                                                                                                                2981 non-null   object
#  22  NIVEL                                                                                                                      2981 non-null   object
#  23  FAIXA SALARIAL                                                                                                             3694 non-null   object
#  24  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?                                                                     3694 non-null   object
#  25  QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  3694 non-null   object
# dtypes: bool(1), float64(1), object(24)
# memory usage: 838.5+ KB

# %% [markdown]
# ### Trabalhando coluna de gênero

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados['GENERO'] = dados['GENERO'].fillna("Prefiro não informar")

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %% [markdown]
# ### Trabalhando coluna de Idade

# %%
dados['IDADE'].isnull().value_counts()
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?'],
#       dtype='object')

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %%
media_17_21 = dados[dados['FAIXA IDADE']=='17-21']['IDADE'].mean()

# %%
dados.loc[(dados['FAIXA IDADE'] == '17-21') & (dados['IDADE'].isnull()), 'IDADE'] = media_17_21

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+    68
# Name: count, dtype: int64

# %%
dados[dados['FAIXA IDADE']=='55+']['IDADE']
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %%
media_geral = dados['IDADE'].mean()
media_geral
# Out:
# np.float64(31.153517220250375)

# %%
dados.loc[(dados['FAIXA IDADE']=='55+') & (dados['IDADE'].isnull()), 'IDADE'] = media_geral

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ### Tratando coluna salário

# %%
dados[dados['FAIXA SALARIAL'].isnull()]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 12    zwr9hqcpg513kaopenzwr9hibaqmldto   31.0       30-34  Masculino
# 28    ztgepgj82o9oix0nztgepq2trcay6gpv   24.0       22-24   Feminino
# 34    zsa9i6njd3e594mw0tvlk4zsa9iw86i9   24.0       22-24   Feminino
# 39    zr4b2vm7dapp3linwqwn7zr4b2vmagqx   32.0       30-34  Masculino
# 63    zm7o5yquakof0j6zm7vh3o0letznhdvh   26.0       25-29  Masculino
# ...                                ...    ...         ...        ...
# 4242  09oxwp6lsdwhw09ox1uobuxa8cq2pzma   26.0       25-29  Masculino
# 4252  064pe9b1htw7mflhif064pe95dotv6yf   39.0       35-39  Masculino
# 4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29   Feminino
# 4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39  Masculino
# 4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 12           Branca  Não                                                NaN
# 28            Parda  Não  Sim, acredito que a minha a experiência profis...
# 34           Branca  Não  Sim, acredito que a minha a experiência profis...
# 39            Parda  Não  Não acredito que minha experiência profissiona...
# 63           Branca  Não                                                NaN
# ...             ...  ...                                                ...
# 4242         Branca  Não                                                NaN
# 4252          Parda  Não  Não acredito que minha experiência profissiona...
# 4258         Branca  Não  Sim, acredito que a minha a experiência profis...
# 4260          Parda  Não  Não acredito que minha experiência profissiona...
# 4261         Branca  Não                                                NaN
#
#                                   ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 12                                                  NaN            True
# 28         Aprovação em processos seletivos/entrevistas            True
# 34    Quantidade de oportunidades de emprego/vagas r...            True
# 39                                                  NaN            True
# 63                                                  NaN            True
# ...                                                 ...             ...
# 4242                                                NaN            True
# 4252                                                NaN            True
# 4258  Senioridade das vagas recebidas em relação à s...            True
# 4260                                                NaN            True
# 4261                                                NaN            True
#
#             ESTADO ONDE MORA  ...    QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 12            São Paulo (SP)  ...  Trabalho na área Acadêmica/Pesquisador
# 28         Minas Gerais (MG)  ...      Desempregado, buscando recolocação
# 34     Distrito Federal (DF)  ...      Desempregado, buscando recolocação
# 39                Bahia (BA)  ...      Desempregado, buscando recolocação
# 63       Rio de Janeiro (RJ)  ...       Somente Estudante (pós-graduação)
# ...                      ...  ...                                     ...
# 4242          São Paulo (SP)  ...      Desempregado, buscando recolocação
# 4252          São Paulo (SP)  ...           Somente Estudante (graduação)
# 4258       Minas Gerais (MG)  ...       Somente Estudante (pós-graduação)
# 4260              Piauí (PI)  ...      Desempregado, buscando recolocação
# 4261  Rio Grande do Sul (RS)  ...      Desempregado, buscando recolocação
#
#      SETOR NUMERO DE FUNCIONARIOS GESTOR? CARGO COMO GESTOR CARGO ATUAL NIVEL  \
# 12     NaN                    NaN     NaN               NaN         NaN   NaN
# 28     NaN                    NaN     NaN               NaN         NaN   NaN
# 34     NaN                    NaN     NaN               NaN         NaN   NaN
# 39     NaN                    NaN     NaN               NaN         NaN   NaN
# 63     NaN                    NaN     NaN               NaN         NaN   NaN
# ...    ...                    ...     ...               ...         ...   ...
# 4242   NaN                    NaN     NaN               NaN         NaN   NaN
# 4252   NaN                    NaN     NaN               NaN         NaN   NaN
# 4258   NaN                    NaN     NaN               NaN         NaN   NaN
# 4260   NaN                    NaN     NaN               NaN         NaN   NaN
# 4261   NaN                    NaN     NaN               NaN         NaN   NaN
#
#      FAIXA SALARIAL QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 12              NaN                                                NaN
# 28              NaN                                                NaN
# 34              NaN                                                NaN
# 39              NaN                                                NaN
# 63              NaN                                                NaN
# ...             ...                                                ...
# 4242            NaN                                                NaN
# 4252            NaN                                                NaN
# 4258            NaN                                                NaN
# 4260            NaN                                                NaN
# 4261            NaN                                                NaN
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 12                                                  NaN
# 28                                                  NaN
# 34                                                  NaN
# 39                                                  NaN
# 63                                                  NaN
# ...                                                 ...
# 4242                                                NaN
# 4252                                                NaN
# 4258                                                NaN
# 4260                                                NaN
# 4261                                                NaN
#
# [577 rows x 26 columns]

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?'],
#       dtype='object')

# %% [markdown]
# ### Valores discrepantes (outliers)

# %%
lista_idades =[26, 30, 32, 22, 26, 35, 400, 20, 43, 31, 23]

# %%
media = np.mean(lista_idades)
media
# Out:
# np.float64(62.54545454545455)

# %%
desvio = np.std(lista_idades)
desvio
# Out:
# np.float64(106.89532997398872)

# %%
media + 3*desvio
# Out:
# np.float64(383.2314444674207)

# %%
media - 3*desvio
# Out:
# np.float64(-258.1405353765116)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(lista_idades)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a22df554f20>,
#   <matplotlib.lines.Line2D at 0x7a22df48e300>],
#  'caps': [<matplotlib.lines.Line2D at 0x7a22df48ea80>,
#   <matplotlib.lines.Line2D at 0x7a22df48c140>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7a22df557470>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a22df48e390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a22df48c620>],
#  'means': []}

# %%
plt.boxplot(dados['IDADE'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a22df4ec260>,
#   <matplotlib.lines.Line2D at 0x7a22df4ecf80>],
#  'caps': [<matplotlib.lines.Line2D at 0x7a22e00be780>,
#   <matplotlib.lines.Line2D at 0x7a22dfa2adb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7a22df4ee000>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a22dfa29eb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a22df4ed610>],
#  'means': []}

# %%
Q1 = dados['IDADE'].quantile(0.25)
Q1
# Out:
# np.float64(26.0)

# %%
Q3 = dados['IDADE'].quantile(0.75)
Q3
# Out:
# np.float64(35.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(9.0)

# %%
lim_superior = Q3 + (1.5*IQR)
lim_superior
# Out:
# np.float64(48.5)

# %%
lim_inferior = Q1 - (1.5*IQR)
lim_inferior
# Out:
# np.float64(12.5)

# %%
dados['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# de R$ 8.001/mês a R$ 12.000/mês     752
# de R$ 4.001/mês a R$ 6.000/mês      584
# de R$ 6.001/mês a R$ 8.000/mês      527
# de R$ 12.001/mês a R$ 16.000/mês    437
# de R$ 3.001/mês a R$ 4.000/mês      303
# de R$ 2.001/mês a R$ 3.000/mês      285
# de R$ 16.001/mês a R$ 20.000/mês    229
# de R$ 1.001/mês a R$ 2.000/mês      216
# de R$ 20.001/mês a R$ 25.000/mês    134
# de R$ 25.001/mês a R$ 30.000/mês     77
# de R$ 30.001/mês a R$ 40.000/mês     70
# Acima de R$ 40.001/mês               45
# Menos de R$ 1.000/mês                35
# Name: count, dtype: int64

# %%
dados[(dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês')]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 77    zguo6vbcbj53swqvmeplnzgdytmzd1ra   43.0       40-44  Masculino
# 109   z9bpq3edulq2cf0x87z9bpq3m0ng4dpo   33.0       30-34  Masculino
# 220   ybf65rx7jhbsaqadyedrxybf65cnjf3y   34.0       30-34  Masculino
# 222   ybcx01o4hwo337rpcybcx01nh43li4j5   50.0       50-54  Masculino
# 332   xhr5r05iq2cfvt010uxhr5r4vy2hwfpm   34.0       30-34  Masculino
# ...                                ...    ...         ...        ...
# 3891  3a7lwm8fi9mflaic23a7le85pz9zbm00   34.0       30-34  Masculino
# 3896  37h5amfxdw70q58jw7rt37h5amgek38i   31.0       30-34  Masculino
# 4000  2baf3bx82w0sh88q3eikkl92baf3bx8f   41.0       40-44  Masculino
# 4183  0piwql00qmpavk1pt1no0piwqletb3yi   37.0       35-39  Masculino
# 4253  051vmgm053xetlr9051vmy2it5e6q2cv   29.0       25-29  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 77           Branca  Não                                                NaN
# 109           Parda  Não  Não acredito que minha experiência profissiona...
# 220           Parda  Não  Não acredito que minha experiência profissiona...
# 222          Branca  Não                                                NaN
# 332          Branca  Não                                                NaN
# ...             ...  ...                                                ...
# 3891         Branca  Não                                                NaN
# 3896         Branca  Não                                                NaN
# 4000        Amarela  Não  Não acredito que minha experiência profissiona...
# 4183         Branca  Não                                                NaN
# 4253         Branca  Não                                                NaN
#
#      ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL ESTADO ONDE MORA  ...  \
# 77                     NaN            True       Bahia (BA)  ...
# 109                    NaN           False              NaN  ...
# 220                    NaN            True   São Paulo (SP)  ...
# 222                    NaN            True   São Paulo (SP)  ...
# 332                    NaN           False              NaN  ...
# ...                    ...             ...              ...  ...
# 3891                   NaN           False              NaN  ...
# 3896                   NaN            True   São Paulo (SP)  ...
# 4000                   NaN            True   São Paulo (SP)  ...
# 4183                   NaN            True   São Paulo (SP)  ...
# 4253                   NaN            True   São Paulo (SP)  ...
#
#                    QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?  \
# 77                                     Servidor Público
# 109   Vivo fora do Brasil e trabalho para empresa de...
# 220                                     Empregado (CLT)
# 222                    Empreendedor ou Empregado (CNPJ)
# 332   Vivo fora do Brasil e trabalho para empresa de...
# ...                                                 ...
# 3891  Vivo fora do Brasil e trabalho para empresa de...
# 3896  Vivo no Brasil e trabalho remoto para empresa ...
# 4000                                    Empregado (CLT)
# 4183                                    Empregado (CLT)
# 4253                                    Empregado (CLT)
#
#                                SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 77                          Educação         de 501 a 1.000    True
# 109               Finanças ou Bancos         de 501 a 1.000   False
# 220               Internet/Ecommerce         Acima de 3.000   False
# 222   Tecnologia/Fábrica de Software             de 11 a 50    True
# 332                Setor Alimentício         Acima de 3.000   False
# ...                              ...                    ...     ...
# 3891              Internet/Ecommerce            de 51 a 100   False
# 3896  Tecnologia/Fábrica de Software         de 501 a 1.000   False
# 4000              Finanças ou Bancos         Acima de 3.000    True
# 4183                     Outra Opção       de 1.001 a 3.000    True
# 4253             Área de Consultoria       de 1.001 a 3.000   False
#
#             CARGO COMO GESTOR  \
# 77    Team Leader/Tech Leader
# 109                       NaN
# 220                       NaN
# 222                Diretor/VP
# 332                       NaN
# ...                       ...
# 3891                      NaN
# 3896                      NaN
# 4000             Gerente/Head
# 4183             Gerente/Head
# 4253                      NaN
#
#                                             CARGO ATUAL   NIVEL  \
# 77                                                  NaN     NaN
# 109                      Analista de Dados/Data Analyst  Sênior
# 220          Engenheiro de Machine Learning/ML Engineer  Sênior
# 222                                                 NaN     NaN
# 332                                         Outra Opção   Pleno
# ...                                                 ...     ...
# 3891                  Cientista de Dados/Data Scientist   Pleno
# 3896                     Analista de Dados/Data Analyst  Sênior
# 4000                                                NaN     NaN
# 4183                                                NaN     NaN
# 4253  Engenheiro de Dados/Arquiteto de Dados/Data En...  Sênior
#
#                         FAIXA SALARIAL  \
# 77    de R$ 30.001/mês a R$ 40.000/mês
# 109   de R$ 30.001/mês a R$ 40.000/mês
# 220   de R$ 30.001/mês a R$ 40.000/mês
# 222   de R$ 30.001/mês a R$ 40.000/mês
# 332   de R$ 30.001/mês a R$ 40.000/mês
# ...                                ...
# 3891  de R$ 30.001/mês a R$ 40.000/mês
# 3896  de R$ 30.001/mês a R$ 40.000/mês
# 4000  de R$ 30.001/mês a R$ 40.000/mês
# 4183  de R$ 30.001/mês a R$ 40.000/mês
# 4253  de R$ 30.001/mês a R$ 40.000/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 77                                      Mais de 10 anos
# 109                                       de 4 a 6 anos
# 220                                       de 4 a 6 anos
# 222                                     Mais de 10 anos
# 332                                       de 3 a 4 anos
# ...                                                 ...
# 3891                                      de 3 a 4 anos
# 3896                                      de 3 a 4 anos
# 4000                                    Mais de 10 anos
# 4183                                    Mais de 10 anos
# 4253                                      de 4 a 6 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?
# 77    Não tive experiência na área de TI/Engenharia ...
# 109                                      Menos de 1 ano
# 220   Não tive experiência na área de TI/Engenharia ...
# 222                                       de 3 a 4 anos
# 332                                      Menos de 1 ano
# ...                                                 ...
# 3891                                      de 1 a 2 anos
# 3896  Não tive experiência na área de TI/Engenharia ...
# 4000  Não tive experiência na área de TI/Engenharia ...
# 4183                                      de 3 a 4 anos
# 4253                                      de 1 a 2 anos
#
# [70 rows x 26 columns]

# %% [markdown]
# ### Distribuição amostral e intervalo de confiança

# %%
idade = dados['IDADE']

# %%
idade
# Out:
# 0       39.000000
# 1       32.000000
# 2       53.000000
# 3       27.000000
# 4       46.000000
#           ...
# 4266    26.000000
# 4267    30.000000
# 4268    29.000000
# 4269    20.205479
# 4270    24.000000
# Name: IDADE, Length: 4271, dtype: float64

# %%
media_amostral = np.mean(idade)
media_amostral
# Out:
# np.float64(31.153517220250375)

# %%
desvio_amostral = np.std(idade)
desvio_amostral
# Out:
# 6.854238421066827

# %%
nivel_confianca = 0.95

# %%
tamanho_amostra = len(idade)
tamanho_amostra
# Out:
# 4271

# %%
from scipy import stats

# %%
erro_padrao = stats.sem(idade)
erro_padrao
# Out:
# np.float64(0.10489270120685477)

# %%
intervalo_confianca = stats.t.interval(nivel_confianca, tamanho_amostra-1, loc=media_amostral, scale=erro_padrao)
intervalo_confianca
# Out:
# (np.float64(30.947873012475945), np.float64(31.359161428024805))

# %% [markdown]
# ### Featuring engineering

# %%
def preencher_nivel(gestor, nivel):
  if gestor==1:
    return "Pessoa Gestora"
  else:
    return nivel

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?'],
#       dtype='object')

# %%
dados['NOVO_NIVEL'] = dados.apply(lambda x: preencher_nivel(x['GESTOR?'], x['NIVEL']), axis=1)

# %%
dados['NOVO_NIVEL'].value_counts()
# Out:
# NOVO_NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa Gestora     713
# Name: count, dtype: int64

# %%
dados['NIVEL']
# Out:
# 0       Júnior
# 1          NaN
# 2        Pleno
# 3       Sênior
# 4        Pleno
#          ...
# 4266     Pleno
# 4267     Pleno
# 4268       NaN
# 4269    Júnior
# 4270    Júnior
# Name: NIVEL, Length: 4271, dtype: object

# %%
dados = pd.get_dummies(dados, columns=['NIVEL'])

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior'],
#       dtype='object')

# %%
def determinar_geracao(idade):
  if 39<idade<=58:
    return 'Geração X'
  elif 29<idade<=39:
    return 'Millenial'
  elif 13<idade<=29:
    return 'Geração Z'
  else:
    return 'Outra geração'

# %%
dados['GERACAO'] = dados['IDADE'].apply(determinar_geracao)

# %%
dados['GERACAO'].value_counts()
# Out:
# GERACAO
# Geração Z    1999
# Millenial    1761
# Geração X     511
# Name: count, dtype: int64

# %%
dados2 = pd.read_excel('/content/drive/MyDrive/Programaria/Modulo 4 Cópia de Planilha_Aula_parte2.xlsx')

# %%
dados2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
#   Você está satisfeito na sua empresa atual?  \
# 0                                       True
# 1                                      False
# 2                                      False
# 3                                       True
# 4                                      False
#
#   Qual o principal motivo da sua insatisfação com a empresa atual?  \
# 0                                                NaN
# 1  Falta de oportunidade de crescimento no empreg...
# 2  Falta de oportunidade de crescimento no empreg...
# 3                                                NaN
# 4  Falta de oportunidade de crescimento no empreg...
#
#   Você participou de entrevistas de emprego nos últimos 6 meses?  \
# 0  Não participei de entrevistas de emprego/proce...
# 1          Sim, fiz entrevistas mas não fui aprovado
# 2  Não participei de entrevistas de emprego/proce...
# 3               Sim, fui aprovado e mudei de emprego
# 4  Não participei de entrevistas de emprego/proce...
#
#   Você pretende mudar de emprego nos próximos 6 meses?  \
# 0  Não estou buscando e não pretendo mudar de emp...
# 1  Estou em busca de oportunidades dentro ou fora...
# 2  Não estou buscando, mas me considero aberto a ...
# 3  Não estou buscando, mas me considero aberto a ...
# 4  Não estou buscando, mas me considero aberto a ...
#
#   Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?  \
# 0                                         Benefícios
# 1  Remuneração/Salário, Plano de carreira e oport...
# 2  Remuneração/Salário, Flexibilidade de trabalho...
# 3  Remuneração/Salário, Flexibilidade de trabalho...
# 4  Remuneração/Salário, Oportunidade de aprendiza...
#
#             Atualmente qual a sua forma de trabalho?  \
# 0                             Modelo 100% presencial
# 1                             Modelo 100% presencial
# 2  Modelo híbrido com dias fixos de trabalho pres...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#            Qual a forma de trabalho ideal para você?  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
# 1  Modelo híbrido flexível (o funcionário tem lib...
# 2  Modelo híbrido flexível (o funcionário tem lib...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#   Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 0   Vou aceitar e retornar ao modelo 100% presencial
# 1   Vou aceitar e retornar ao modelo 100% presencial
# 2  Vou procurar outra oportunidade no modelo híbr...
# 3  Vou procurar outra oportunidade no modelo híbr...
# 4   Vou aceitar e retornar ao modelo 100% presencial
#
#                Sua empresa passu por Layoff em 2022?  \
# 0  Não ocorreram layoffs/demissões em massa na em...
# 1  Não ocorreram layoffs/demissões em massa na em...
# 2  Não ocorreram layoffs/demissões em massa na em...
# 3  Não ocorreram layoffs/demissões em massa na em...
# 4  Não ocorreram layoffs/demissões em massa na em...
#
#                                              Atuacao  \
# 0                                Engenharia de Dados
# 1                                             Gestor
# 2   desenvolve modelos preditivos e algoritmos de...
# 3   desenvolve modelos preditivos e algoritmos de...
# 4                                      Outra atuação
#
#   Quais das linguagens listadas abaixo você utiliza no trabalho?
# 0                                                SQL
# 1                                                NaN
# 2                                                  1
# 3                                                  0
# 4                                                SQL

# %%
dados = dados.merge(dados2, on='ID', how='left')

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior', 'GERACAO',
#        'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?'],
#       dtype='object')

# %%
dados['Você pretende mudar de emprego nos próximos 6 meses?'].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
 dados['EM_BUSCA'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('em busca', case=False)

# %%
dados['EM_BUSCA'].value_counts()
# Out:
# EM_BUSCA
# False    2332
# True     1364
# Name: count, dtype: int64

# %%
dados['ABERTO_OPORTUNIDADES'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('aberto', case=False)

# %%
dados['ABERTO_OPORTUNIDADES'].value_counts()
# Out:
# ABERTO_OPORTUNIDADES
# False    2342
# True     1354
# Name: count, dtype: int64

# %% [markdown]
# # Correlação

# %%
correlacao_continua = dados['IDADE'].corr(dados['IDADE'])
correlacao_continua
# Out:
# np.float64(1.0)

# %%
from scipy.stats import chi2_contingency

# %%
def cramer_coeficiente(coluna1, coluna2):
  tabela_cruzada = np.array(pd.crosstab(coluna1, coluna2))
  chi2 = chi2_contingency(tabela_cruzada)[0]
  soma = np.sum(tabela_cruzada)
  mini = min(tabela_cruzada.shape)-1
  cramer = np.sqrt((chi2/soma*mini))
  return cramer

# %%
cramer_coeficiente(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
# Out:
# np.float64(0.2699463948288086)

# %%
tabela_cruzada = pd.crosstab(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
tabela_cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# COR/RACA/ETNIA
# Amarela                              7                      15
# Branca                             127                     365
# Indígena                             0                       2
# Outra                                0                       0
# Parda                               50                     178
# Prefiro não informar                 1                       2
# Preta                                6                      51
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# COR/RACA/ETNIA
# Amarela                                  50        14
# Branca                                  999       355
# Indígena                                  4         2
# Outra                                     6         3
# Parda                                   333       113
# Prefiro não informar                     14         1
# Preta                                   104        33
#
# NIVEL DE ENSINO       Não tenho graduação formal  Prefiro não informar  \
# COR/RACA/ETNIA
# Amarela                                        2                     0
# Branca                                        65                     8
# Indígena                                       0                     0
# Outra                                          1                     0
# Parda                                         33                     3
# Prefiro não informar                           0                     1
# Preta                                          9                     0
#
# NIVEL DE ENSINO       Pós-graduação
# COR/RACA/ETNIA
# Amarela                          40
# Branca                          827
# Indígena                          3
# Outra                             7
# Parda                           344
# Prefiro não informar              7
# Preta                            88

# %%
dados.to_csv('/content/drive/MyDrive/Programaria/analise_dados.csv', index=False)

# %% [markdown]
# # Conectando SQL com pandas

# %%
import sqlite3

# %%
query = "SELECT * FROM Municipios_Brasileiros WHERE Cidade = 'Itaquaquecetuba';"

# %%
query
# Out:
# "SELECT * FROM Municipios_Brasileiros WHERE Cidade = 'Itaquaquecetuba';"

# %%
pd.read_sql(query, con=conexao)

# %%
dados = pd.read_csv('/content/drive/MyDrive/Programaria/analise_dados.csv')

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior', 'GERACAO',
#        'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?',
#        'EM_BUSCA', 'ABERTO_OPORTUNIDADES'],
#       dtype='object')

# %%
lista_estados = (dados['UF ONDE MORA'].unique())

# %%
query = '''SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.renda) FROM Municipios_Brasileiros
          INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID
          WHERE Municipios_Brasileiros.Estado IN ({})
          GROUP BY Municipios_Brasileiros.Estado;'''.format(','.join(['?' for _ in lista_estados]))

# %%
estados_renda = pd.read_sql(query, con=conexao, params=lista_estados)

# %%
print(query)
# Out:
# SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.renda) FROM Municipios_Brasileiros
#           INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID
#           WHERE Municipios_Brasileiros.Estado IN (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
#           GROUP BY Municipios_Brasileiros.Estado;

# %%
dados.rename(columns={'UF ONDE MORA': 'Estado'}, inplace=True)

# %%
dados = dados.merge(estados_renda, on='Estado', how='left')

# %% [markdown]
# # Visualização de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
dados = pd.read_excel("/content/Cópia de analise_dados - TRAT.xlsx")

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GEARACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?',
#        'EM_BUSCA', 'ABERTO_OPORTUNIDADES'],
#       dtype='object')

# %%
dados.head()
# Out:
#                                  ID  IDADE FAIXA IDADE     GENERO  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.00       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd  32.00       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.00       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.00       25-29  Masculino
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.00       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
#                           ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0                                           NaN            True
# 1  Aprovação em processos seletivos/entrevistas            True
# 2                                           NaN            True
# 3                                           NaN            True
# 4                                           NaN            True
#
#         ESTADO ONDE MORA  ...  \
# 0  Distrito Federal (DF)  ...
# 1              Pará (PA)  ...
# 2  Distrito Federal (DF)  ...
# 3      Minas Gerais (MG)  ...
# 4              Pará (PA)  ...
#
#   Você pretende mudar de emprego nos próximos 6 meses?  \
# 0  Não estou buscando e não pretendo mudar de emp...
# 1  Estou em busca de oportunidades dentro ou fora...
# 2  Não estou buscando, mas me considero aberto a ...
# 3  Não estou buscando, mas me considero aberto a ...
# 4  Não estou buscando, mas me considero aberto a ...
#
#   Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?  \
# 0                                         Benefícios
# 1  Remuneração/Salário, Plano de carreira e oport...
# 2  Remuneração/Salário, Flexibilidade de trabalho...
# 3  Remuneração/Salário, Flexibilidade de trabalho...
# 4  Remuneração/Salário, Oportunidade de aprendiza...
#
#             Atualmente qual a sua forma de trabalho?  \
# 0                             Modelo 100% presencial
# 1                             Modelo 100% presencial
# 2  Modelo híbrido com dias fixos de trabalho pres...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#            Qual a forma de trabalho ideal para você?  \
# 0  Modelo híbrido com dias fixos de trabalho pres...
# 1  Modelo híbrido flexível (o funcionário tem lib...
# 2  Modelo híbrido flexível (o funcionário tem lib...
# 3  Modelo híbrido flexível (o funcionário tem lib...
# 4                             Modelo 100% presencial
#
#   Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?  \
# 0   Vou aceitar e retornar ao modelo 100% presencial
# 1   Vou aceitar e retornar ao modelo 100% presencial
# 2  Vou procurar outra oportunidade no modelo híbr...
# 3  Vou procurar outra oportunidade no modelo híbr...
# 4   Vou aceitar e retornar ao modelo 100% presencial
#
#                Sua empresa passu por Layoff em 2022?  \
# 0  Não ocorreram layoffs/demissões em massa na em...
# 1  Não ocorreram layoffs/demissões em massa na em...
# 2  Não ocorreram layoffs/demissões em massa na em...
# 3  Não ocorreram layoffs/demissões em massa na em...
# 4  Não ocorreram layoffs/demissões em massa na em...
#
#                                              Atuacao  \
# 0                                Engenharia de Dados
# 1                                             Gestor
# 2  desenvolve modelos preditivos e algoritmos de ...
# 3  desenvolve modelos preditivos e algoritmos de ...
# 4                                      Outra atuação
#
#   Quais das linguagens listadas abaixo você utiliza no trabalho? EM_BUSCA  \
# 0                                                SQL                 0.00
# 1                                                NaN                 1.00
# 2                                                  1                 0.00
# 3                                                  0                 0.00
# 4                                                SQL                 0.00
#
#    ABERTO_OPORTUNIDADES
# 0                  0.00
# 1                  0.00
# 2                  1.00
# 3                  1.00
# 4                  1.00
#
# [5 rows x 46 columns]

# %%
genero_counts = dados['GENERO'].value_counts()

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GEARACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?',
#        'EM_BUSCA', 'ABERTO_OPORTUNIDADES'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.bar(height = genero_counts.values, x = genero_counts.index)
plt.title('Quantidade de pessoas por gênero na área de dados')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-1078642125.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns

# %%
plt.figure()
sns.countplot(data=dados, x='GENERO', palette = 'pastel')
plt.title('Quantidade de pessoas por gênero na área de dados')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-2177754421.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GEARACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#        'Você está satisfeito na sua empresa atual?',
#        'Qual o principal motivo da sua insatisfação com a empresa atual?',
#        'Você participou de entrevistas de emprego nos últimos 6 meses?',
#        'Você pretende mudar de emprego nos próximos 6 meses?',
#        'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?',
#        'Atualmente qual a sua forma de trabalho?',
#        'Qual a forma de trabalho ideal para você?',
#        'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?',
#        'Sua empresa passu por Layoff em 2022?', 'Atuacao',
#        'Quais das linguagens listadas abaixo você utiliza no trabalho?',
#        'EM_BUSCA', 'ABERTO_OPORTUNIDADES'],
#       dtype='object')

# %%
dados['IDADE'] = dados['IDADE'].astype(str)

# %%
salario_por_idade = dados.groupby('IDADE')['SALARIO'].mean()

# %%
salario_por_idade
# Out:
# IDADE
# 18.0    4230.31
# 19.0    4519.59
# 20.0    5004.27
# 21.0    4578.74
# 22.0    4394.69
# 23.0    5602.41
# 24.0    6151.62
# 25.0    7616.39
# 26.0    7700.07
# 27.0    8237.43
# 28.0    9737.94
# 29.0    9554.85
# 30.0   10316.41
# 31.0   10021.46
# 32.0   10843.20
# 33.0   11592.72
# 34.0   12294.64
# 35.0   12435.85
# 36.0   12267.97
# 37.0   12613.53
# 38.0   13802.72
# 39.0   13309.08
# 40.0   15028.03
# 41.0   13578.88
# 42.0   11801.04
# 43.0   14349.73
# 44.0   14665.77
# 45.0   16103.43
# 46.0   11913.71
# 47.0   11156.03
# 48.0   12249.71
# 49.0   13537.45
# 50.0   15740.01
# 51.0    8977.90
# 52.0   11779.48
# 53.0    9850.00
# 54.0   13644.14
# Name: SALARIO, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(salario_por_idade.index, salario_por_idade.values, marker='o', linestyle='--')
plt.title('Média de salário por idade')
plt.xlabel('Idade')
plt.ylabel('Média de salário')
plt.grid(True)
plt.show()

# %%
print(salario_por_idade.index)
print(salario_por_idade.index.dtype)
# Out:
# Index(['18.0', '19.0', '20.0', '21.0', '22.0', '23.0', '24.0', '25.0', '26.0',
#        '27.0', '28.0', '29.0', '30.0', '31.0', '32.0', '33.0', '34.0', '35.0',
#        '36.0', '37.0', '38.0', '39.0', '40.0', '41.0', '42.0', '43.0', '44.0',
#        '45.0', '46.0', '47.0', '48.0', '49.0', '50.0', '51.0', '52.0', '53.0',
#        '54.0'],
#       dtype='object', name='IDADE')
# object

# %%
salario_por_idade.index = salario_por_idade.index.astype(str)

# %%
salario_por_idade_df = salario_por_idade.reset_index()

# %%
plt.figure(figsize=(10,6))
plt.plot(salario_por_idade_df['IDADE'], salario_por_idade_df['SALARIO'], marker='o', linestyle='--')
plt.title('Média de salário por idade')
plt.xlabel('Idade')
plt.ylabel('Média de salário')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout
plt.show()

# %%
import plotly.express as px

# %%
fig=px.line(salario_por_idade_df, x='IDADE', y='SALARIO', title='Média de salário por idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3a666f5f-11b3-4307-9793-849230d074f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a666f5f-11b3-4307-9793-849230d074f1")) {                    Plotly.newPlot(                        "3a666f5f-11b3-4307-9793-849230d074f1",                        [{"hovertemplate":"IDADE=%{x}\u003cbr\u003eSALARIO=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["18.0","19.0","20.0","21.0","22.0","23.0","24.0","25.0","26.0","27.0","28.0","29.0","30.0","31.0","32.0","33.0","34.0","35.0","36.0","37.0","38.0","39.0","40.0","41.0","42.0","43.0","44.0","45.0","46.0","47.0","48.0","49.0","50.0","51.0","52.0","53.0","54.0"],"xaxis":"x","y":[4230.307692307692,4519.590909090909,5004.272727272727,4578.73717948718,4394.689814814815,5602.4068965517245,6151.622448979592,7616.3923357664235,7700.071174377224,8237.429765886287,9737.938144329897,9554.85314624506,10316.41268548387,10021.462608695652,10843.197777777777,11592.718588888889,12294.640211640211,12435.845103448277,12267.966532467532,12613.528355932203,13802.724871794871,13309.082893203882,15028.03271641791,13578.880952380952,11801.037037037036,14349.732274509804,14665.770142857144,16103.431512195122,11913.709677419354,11156.03125,12249.714285714286,13537.45,15740.010176470589,8977.9,11779.475,9850.0,13644.142],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333 ...

# %%
plt.figure(figsize=(15,5))
plt.scatter(salario_por_idade_df['IDADE'], salario_por_idade_df['SALARIO'], alpha=0.5)
plt.title('Dispersão de salário por idade')
plt.xlabel('Idade')
plt.ylabel('Salário')
plt.grid(True)
plt.show()

# %%
fig = px.scatter(salario_por_idade_df, x='IDADE', y='SALARIO', title='Dispersão de salário por idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5da2a08f-8c8b-495a-9c14-4222883bbfcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5da2a08f-8c8b-495a-9c14-4222883bbfcb")) {                    Plotly.newPlot(                        "5da2a08f-8c8b-495a-9c14-4222883bbfcb",                        [{"hovertemplate":"IDADE=%{x}\u003cbr\u003eSALARIO=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["18.0","19.0","20.0","21.0","22.0","23.0","24.0","25.0","26.0","27.0","28.0","29.0","30.0","31.0","32.0","33.0","34.0","35.0","36.0","37.0","38.0","39.0","40.0","41.0","42.0","43.0","44.0","45.0","46.0","47.0","48.0","49.0","50.0","51.0","52.0","53.0","54.0"],"xaxis":"x","y":[4230.307692307692,4519.590909090909,5004.272727272727,4578.73717948718,4394.689814814815,5602.4068965517245,6151.622448979592,7616.3923357664235,7700.071174377224,8237.429765886287,9737.938144329897,9554.85314624506,10316.41268548387,10021.462608695652,10843.197777777777,11592.718588888889,12294.640211640211,12435.845103448277,12267.966532467532,12613.528355932203,13802.724871794871,13309.082893203882,15028.03271641791,13578.880952380952,11801.037037037036,14349.732274509804,14665.770142857144,16103.431512195122,11913.709677419354,11156.03125,12249.714285714286,13537.45,15740.010176470589,8977.9,11779.475,9850.0,13644.142],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"] ...
